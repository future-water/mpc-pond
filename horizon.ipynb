# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
N = 1000
t_range = np.linspace(0, 3600*4, N)
u = -0.1 * np.cos(t_range / 3600)
U = np.column_stack([u, 0.5 * u])

# %%
sns.set_palette('husl', 4)
plt.plot(t_range, U)
